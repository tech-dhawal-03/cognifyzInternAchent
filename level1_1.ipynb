# %% [markdown]
# <a href="https://colab.research.google.com/github/tech-dhawal-03/cognifyzInternAchent/blob/main/level1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Level 1 : Task 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# '6th sem .pdf'
# 'Assignment 1.xlsx'
# 'Assignment 2.xlsx'
# 'Assignment 3.xlsx'
# 'Colab Notebooks'
# 'Dataset .csv'
# 'Getting started.pdf'
#  image.jpg
#  IMG-20230226-WA0000.jpg
#  IMG-20230820-WA0004.jpg
#  IMG-20231021-WA0019.jpg
#  IMG_20240102_144353_635.jpg
# 'NEC ASSIGNMENT 1 BY ACHENT UPADHYAY.xlsx'
# 'NEC ASSIGNMENT 2 BY ACHENT UPADHYAY.xlsx'
# 'NEC ASSIGNMENT 3 BY ACHENT UPADHYAY.xlsx'
# 'NEC ASSIGNMENT 4 BY ACHENT UPADHYAY.xlsx'
# 'NEC Assignment 5 BY ACHENT UPADHYAY.xlsx'
# 'NEC ASSIGNMENT 6 BY ACHENT UPADHYAY.xlsx'
# 'NEC ASSIGNMENT 7 BY ACHENT UPADHYAY.xlsx'
# 'Power Electronics PPT.pdf'
#  PXL_20221119_052133449.MP~2.jpg
#  PXL_20221230_122359326.NIGHT~2.jpg
#  PXL_20230208_160738631.PORTRAIT~2.jpg
#  PXL_20230407_150458916.jpg
# 'Requirement Engineering_ Definition Requirement Engineering Activity.gdoc'
#  Screenshot_20240216-135714.png
#  Screenshot_20240220-140630.png
#  Screenshot_20240312-133005.png
# 'Symmetrical Components.pptx'
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset .csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#rows and columns
df.shape
# Out:
# (9551, 21)

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna()
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Distribution plot
sns.countplot(x='Aggregate rating', data=df)
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Aggregate rating')
plt.ylabel('Count')
plt.show()

# Check class imbalance
print("\nRating value counts:\n", df['Aggregate rating'].value_counts())
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution plot
sns.countplot(x='Aggregate rating', data=df)
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Aggregate rating')
plt.ylabel('Count')
plt.show()

# Check class imbalance
print("\nRating value counts:\n", df['Aggregate rating'].value_counts())
# Out:
# Rating value counts:
#  Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64
# Rating value counts:
#  Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# ...
